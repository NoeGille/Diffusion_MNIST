# %%
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision import transforms
import matplotlib.pyplot as plt
from torch import nn
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

preprocess = transforms.Compose(
    [
        transforms.ToTensor(),
        transforms.Normalize([0.5], [0.5]),
    ]
)
batch_size = 128
dataset = MNIST(root='', train=True, download=True, transform=preprocess)
loader_train = DataLoader(dataset, batch_size, shuffle=True)
plt.imshow(dataset[0][0].squeeze(), cmap='gray')
plt.colorbar()
plt.show()

# %%
from unet import Conditional_UNet

model = Conditional_UNet(in_channels=1, out_channels=1, block_out_channels=[64, 128],)
model.to(device)
model_state = torch.load('model.pth')
model.load_state_dict(model_state)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       3 model = Conditional_UNet(in_channels=1, out_channels=1, block_out_channels=[64, 128],)
#       4 model.to(device)
# ----> 5 model_state = torch.load('model.pth')['model_state_dict']
#       6 model.load_state_dict(model_state)
#       7 model.eval()
#
# KeyError: 'model_state_dict'
